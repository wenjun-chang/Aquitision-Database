# %% [markdown]
# # Parsing Company 10Ks From the SEC

# %% [markdown]
# In this module, now that we can grab any filing we want from the daily-index filings we are going to move on to the next topic parsing financial documents. The easiest one we can start with is the 10K because the underlying structure provided to us will make grabbing the data accessible and quick. We will only focus on the data tables as this is separated from the document itself. However, in time, we will explore how to parse the different components of the 10K.
#
# ***
#
# ## Import the libraries
# This module will require only three libraries, the first is the `requests` library for making the URL requests, `bs4` to parse the files and content, and finally `pandas` which will be used for taking our cleaned data and giving it structure.

# %%
# import scraping packages
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import os
import unicodedata

# %%
# import packages for getting SEC files as well as CIK numbers
# FilingType gives the 100 type of files to choose from
# Filing is the class of fetched company items
from secedgar.filings import Filing, FilingType

# CIKLookup is for looking at cik of companies, with either name or ticker, case-insensitive
from secedgar.filings.cik_lookup import CIKLookup
# get dict for all ticker/name -> CIK mapping
from secedgar.utils import get_cik_map

# datetime is needed for start_date or end_date in Filing()
from datetime import datetime

# %%
# get filepath 
relative_fp = os.path.realpath(os.getcwd())
fp = relative_fp + 'randomly_selected_firms'

# load data
df = pd.read_csv(fp)
df.drop(df.columns[[0]], axis=1, inplace=True)
df
# Out:
#                       Information Technology  \
# 0                           Qumu (NAS: QUMU)
# 1  Micronet Enertec Technologies (NAS: MICT)
# 2            Activision Blizzard (NAS: ATVI)
# 3                  Elasticsearch (NYS: ESTC)
# 4                 Aviat Networks (NAS: AVNW)
#
#   Consumer Products and Services (B2C)                          Healthcare  \
# 0           XpresSpa Group (NAS: XSPA)        Molina Healthcare (NYS: MOH)
# 1      Winnebago Industries (NYS: WGO)    Capital Senior Living (NYS: CSU)
# 2                    Heska (NAS: HSKA)     Akebia Therapeutics (NAS: AKBA)
# 3      Turning Point Brands (NYS: TPB)  Select Medical Holdings (NYS: SEM)
# 4          Century Casinos (NAS: CNTY)     Blueprint Medicines (NAS: BPMC)
#
#                                    Energy  \
# 0    Natural Resource Partners (NYS: NRP)
# 1  FTS International Services (ASE: FTSI)
# 2                    ChampionX (NYS: CHX)
# 3                         Hess (NYS: HES)
# 4                 Schlumberger (NYS: SLB)
#
#                             Financial Services      Materials and Resources  \
# 0                         Envestnet (NYS: ENV)           Celanese (NYS: CE)
# 1              Legacy Housing Corp (NAS: LEGH)  Compass Minerals (NYS: CMP)
# 2       Permian Basin Royalty Trust (NYS: PBT)          Hawkins (NAS: HWKN)
# 3          Marine Petroleum Trust (NAS: MARPS)   Hycroft Mining (NAS: HYMC)
# 4  North European Oil Royalty Trust (NYS: NRT)  Pacific Ethanol (NAS: PEIX)
#
#   Business Products and Services (B2B)
# 0        Wrap Technologies (NAS: WRTC)
# 1               Red Violet (NAS: RDVT)
# 2            Meritage Homes (NYS: MTH)
# 3         Cavco Industries (NAS: CVCO)
# 4      Lakeland Industries (NAS: LAKE)

# %%
#df['Information Technology'].to_numpy()

# %%
#get name, ticker and sector
name_ticker_sector = []

for sector in df.columns:
    for company_name in df[sector].to_list():
        
        index_of_colon = company_name.index(':')
        index_of_right_paran = company_name.index(')')

        # get the ticker of the current firm
        ticker = company_name[index_of_colon+1:index_of_right_paran].strip()
        
        name_ticker_sector.append([company_name, ticker, sector]) 

name_ticker_sector = np.array(name_ticker_sector, dtype = str)

# %%
# get CIK number for each firm
tickers = name_ticker_sector[:, 1].tolist()
CIK_dict = CIKLookup(tickers).lookup_dict

# %%
# save this for viewing purpose
'''
save_data = pd.DataFrame(name_ticker_sector)
save_data.columns = ['Company Name', 'Ticker', 'Sector']
save_data['Company Name'] = [name[:name.index('(')].strip() for name in save_data['Company Name']]
save_data
save_data.to_csv('company basic info')
'''
# Out:
# "\nsave_data = pd.DataFrame(name_ticker_sector)\nsave_data.columns = ['Company Name', 'Ticker', 'Sector']\nsave_data['Company Name'] = [name[:name.index('(')].strip() for name in save_data['Company Name']]\nsave_data\nsave_data.to_csv('company basic info')\n"

# %%
#CIK_dict['MICT']

# %%
# store the info for each firm in df, before we start web scraping 10Ks
firms_info = []

for company_list in name_ticker_sector:
    company_name = company_list[0]
    company_ticker = company_list[1]
    company_sector = company_list[2]
    company_cik = CIK_dict[company_ticker]
    
    # base url for every search 10-K page on SEC.org
    search_10K_page_base_url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=|&type=10-k'

    # get firm-specific url
    search_10K_page_url = search_10K_page_base_url.replace('|', company_cik)

    # connect to page and search
    search_page = requests.get(search_10K_page_url).content
    soup = BeautifulSoup(search_page, 'html')

    # store report numbers for each firm
    ###can do later

    # find the section denoting report number
    for td_instance in soup.find_all('td',{'class':'small'}):
        text = td_instance.text
        
        # skip 10-K/A files which are amendments
        if '[Amend]' in text:
            #print('10K/A file encountered')
            continue
        
        # parse to get each report number
        index_of_start = text.find('Acc-no:')
        index_of_end = text.find('(34 Act)') # stop before '('

        # some old ones has no (34 Act)
        if index_of_end == -1:
            index_of_end = text.find('Size:')

        if index_of_start == -1 or index_of_end == -1:
            # guess no annual report in here
            print('no annual report in this <td> class')
            print(td_instance.text)
            continue

        index_of_start += len('Acc-no:') # start after this string

        # get report number
        report_number = text[index_of_start: index_of_end]
        # remove - and whitespace
        report_number = report_number.strip().replace('-', '')
        # find date
        report_date = td_instance.findNext('td').text
        # update df
        #print(pd.DataFrame([name, report_number, report_date], columns=list(firms_info.columns)))
        firms_info.append([company_name, company_ticker, company_cik, company_sector, report_number, report_date])

#convert to dataframe
firms_info = pd.DataFrame(firms_info, columns=['Company Name', 'Ticker', 'CIK', 'Sector', '10-K Report Number', '10-K Report Date'])
firms_info['Company Name'] = [name[:name.index('(')].strip() for name in firms_info['Company Name']]

# %%
firms_info.head()
# Out:
#   Company Name Ticker         CIK                  Sector  10-K Report Number  \
# 0         Qumu   QUMU  0000892482  Information Technology  000089248220000007
# 1         Qumu   QUMU  0000892482  Information Technology  000089248219000013
# 2         Qumu   QUMU  0000892482  Information Technology  000089248218000015
# 3         Qumu   QUMU  0000892482  Information Technology  000089248217000024
# 4         Qumu   QUMU  0000892482  Information Technology  000089248216000029
#
#   10-K Report Date
# 0       2020-03-06
# 1       2019-03-15
# 2       2018-03-23
# 3       2017-03-31
# 4       2016-03-15

# %%
#firms_info.iloc[0,:].to_list()+['s']

# %%
#report_number = firms_info.iloc[0,:]['10-K Report Number']
#CIK = firms_info.iloc[0,:]['CIK']
#xlm_base_url = r'https://www.sec.gov/Archives/edgar/data/CIK/report_number/FilingSummary.xml'
#xlm_base_url.replace('CIK', CIK).replace('report_number', report_number)

# %%
#get_10_K_page_url
def get_10_K_page_url(xml_summary):
    page_10K_url = xml_summary.replace('/FilingSummary.xml', '')
    page_10K_url = page_10K_url[:-8] + '-' + page_10K_url[-8:]
    page_10K_url = page_10K_url[:-6] + '-' + page_10K_url[-6:]
    page_10K_url += '-index.htm'
    return page_10K_url

#get 10 K html text file
def get_10_K_txt(xml_summary):
    page_10K_url = get_10_K_page_url(xml_summary)
    return page_10K_url.replace('-index.htm', '.txt')
get_10_K_page_url('https://www.sec.gov/Archives/edgar/data/0000892482/000089248220000007/FilingSummary.xml')
get_10_K_txt('https://www.sec.gov/Archives/edgar/data/0000892482/000089248220000007/FilingSummary.xml')
# Out:
# 'https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-20-000007.txt'

# %%
# decode weird strings...not really working
def restore_windows_1252_characters(restore_string):
    """
        Replace C1 control characters in the Unicode string s by the
        characters at the corresponding code points in Windows-1252,
        where possible.
    """

    def to_windows_1252(match):
        try:
            return bytes([ord(match.group(0))]).decode('windows-1252')
        except UnicodeDecodeError:
            # No character at the corresponding code point: remove it.
            return ''
        
    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# %%
#import webbrowser
#webbrowser.open_new_tab('sec_data\\nmsl.html')

# %%
############################################
# helper functions for reports without .xlm summary
# older ones before 2012
############################################
def parse_acquisition_table(table_instance): # a bs4 table instance
    acquisition_related = False
    
    # define a dictionary that will store the different parts of the statement.
    table_data = {}
    table_data['headers'] = []
    table_data['sections'] = []
    table_data['data'] = []

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(table_instance.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # get data by row
        reg_row = [ele.text.strip() for ele in cols] # remove unicode char
        table_data['data'].append(reg_row)

        if True in ['acquisition' in element.lower() for element in reg_row]:
            acquisition_related = True
        '''
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            table_data['data'].append(reg_row)
                        
            if True in ['acquisition' in element.lower() for element in reg_row]:
                acquisition_related = True
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            table_data['sections'].append(sec_row)
            
            if True in ['acquisition' in element.lower() for element in sec_row]:
                acquisition_related = True
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [unicodedata.normalize('NFKD',ele.text.strip()) for ele in row.find_all('th')]
            table_data['headers'].append(hed_row)
             
            if True in ['acquisition' in element.lower() for element in hed_row]:
                acquisition_related = True
            
        else:            
            print('We encountered an error.')
        ''' 
    '''
    # turn to dataframe
    table = pd.DataFrame(table_data['data'])
    if acquisition_related: 
        # only return when it is acquisition related
        return table
    return # return None if not
    '''
    return acquisition_related

# get acquisition related reports for older 10-Ks using .txt html url, return a list of urls where we save them
def get_info_from_txt(txt_url, name):
    
    content = requests.get(txt_url).content
    soup = BeautifulSoup(content, 'html')
    # get notes sections for acquisition
    
    stuff = []
    bolds = soup.find_all('b')
    if bolds is not None:
        for bold_instance in bolds:
            bold_font = bold_instance.findChild('font' , recursive=False)
            if bold_font is not None:
                note_html = str(bold_font) # new way

                bold_text = bold_font.text
                if bold_text.lower() == 'acquisitions':
                    #acquisition_notes = bold_text + '\n'

                    # this is the next note section's title
                    next_bold_instance = bold_instance.find_next('b')
                    div_to_stop = next_bold_instance.parent

                    # the paragraphs we want
                    div_instance = bold_instance.find_next('div')

                    while div_instance != div_to_stop:
                        #paragraph = unicodedata.normalize('NFKD', div_instance.text)
                        #acquisition_notes += paragraph

                        # new way
                        note_html += str(div_instance)

                        div_instance = div_instance.find_next('div')

                    #stuff.append(acquisition_notes.encode('ascii', 'ignore')) # remove unicode char
                    # new way
                    stuff.append(note_html) # remove unicode char

    # get table sections for acquisition
    tables = soup.find_all('table')
    if tables is not None:
        for table_instance in tables:
                acquisition_related = parse_acquisition_table(table_instance)
                if acquisition_related: # if table is not None:
                    stuff.append(table_instance)

    report_urls = []
    # for all related stuff, write to html and get the link for them
    if stuff:
        for index, html_instance in enumerate(stuff):
            report_url = add_link_and_write(html_instance, name + '_report_' + str(index), dir_name='sec_data')
            report_urls.append(['report ' + str(index), report_url])

    return report_urls

# add a parent tag for the html instanse parsed
def wrap(to_wrap, wrap_in):
    contents = to_wrap.replace_with(wrap_in)
    wrap_in.append(contents)
    
# add link to the html instance we have s.t. we can write it to a html file and call later
def add_link_and_write(html_instance, link_name, dir_name='sec_data'):
    # turn tag into a bs4 instance
    info = BeautifulSoup(str(html_instance))
    wrap(info.table, info.new_tag('a'))
    
    url = r"file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\{}\{}.html".format(dir_name, link_name)
    info.a['href'] = url
    #<a href="where/you/want/the/link/to/go">text of the link</a>
    
    # write to html
    f = open('{}\\{}.html'.format(dir_name, link_name),'wb')
    f.write(str(info).encode('ascii', 'ignore'))
    f.close()
    
    return url

# %%
# main function
def find_relevent_reports(firms_info):
    # to be returned
    #relevant_table_links = []
    # to be returned and saved for Professor
    relevant_table_links = pd.DataFrame(' ', index=list(firms_info['Ticker'].unique()), columns=np.arange(1950,2021)[::-1].astype(str))
    
    # failed to parse one
    failures = 0
    failed_table_links = []
    
    # base link for every xlm doc for each 10-K
    xlm_base_url = r'https://www.sec.gov/Archives/edgar/data/CIK/report_number/FilingSummary.xml'
    
    # for each 10-K we have
    for i in range(firms_info.shape[0]):
        
        #if i > 10:# or i > 200:
        #    continue
            
        print(i)
        # current row
        report_info_df = firms_info.iloc[i,:]
        #if report_info_df['Ticker'] != 'ATVI':
        #    continue
        
        print(report_info_df['Ticker'])
        print(report_info_df['10-K Report Date'])
        print('-'*100)
        
        # xlm link for current 10-K
        xml_summary = xlm_base_url.replace('CIK', report_info_df['CIK']).replace('report_number', report_info_df['10-K Report Number'])
    
        # define a new base url that represents the filing folder. This will come in handy when we need to download the reports.
        base_url = xml_summary.replace('FilingSummary.xml', '')
        
        print(xml_summary)
        
        try:
            # request and parse the content
            content = requests.get(xml_summary).content
            soup = BeautifulSoup(content, 'lxml')
            
        except:
            #print(report_info_df['Company Name'])
            print('Link does not exist')
            print(xml_summary)
            print('-'*100)

        # find the 'myreports' tag because this contains all the individual reports submitted.
        reports = soup.find('myreports')

        '''
        # some AVTI .xlm has no htmlfilename but only xml instance, which is not readable... 
        if report_info_df['Ticker'] in ['ATVI', 'NRP', 'HES', 'SLB', 'CE'] and int(report_info_df['10-K Report Date'].split('-')[0]) <= 2011:
            continue
            # one more try with Report
            #reports = soup.find('report')
            # print(reports)
        '''
        if reports == None:
            # this is the case when the 10-Ks are early than (including 2011)
            # no .xlm summary exist so directly parse .txt html file
            print('Directly parse .txt html file')
            try:
                page_10_K_url = get_10_K_page_url(xml_summary)
                txt_url = get_10_K_txt(xml_summary)
                reports_url = get_info_from_txt(txt_url, name=report_info_df['Ticker']+'_'+report_info_df['10-K Report Date'])

                # of form [report name, report url]
                for report_name_and_url in reports_url:

                    #relevant_table_links.append(report_info_df.tolist() + [page_10_K_url] + report_url)
                    relevant_table_links.loc[report_info_df['Ticker'], report_info_df['10-K Report Date'].split('-')[0]] += report_name_and_url[1] + ' | '

                    print(page_10_K_url)
                    print(report_name_and_url[0])
                    print(report_name_and_url[1])
                    print('-'*100)

            # real issue didnt catch
            except:
                print('got fucked 1!')
                print(get_10_K_txt(xml_summary))
                print('-'*100)
                failures += 1
                failed_table_links.append([report_info_df['Ticker'], report_info_df['10-K Report Date'], get_10_K_txt(xml_summary)])
                continue
            
        else: 
            # loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
            try:
                for report in reports.find_all('report')[:-1]:

                    # acquisition related
                    # what we want
                    if 'acquisition' in report.shortname.text.lower() or 'aquisition' in report.longname.text.lower():

                        # update our list
                        page_10_K_url = get_10_K_page_url(xml_summary)
                        table_name = report.shortname.text # report.longname.text # both long or short is fine
                        table_url = base_url + report.htmlfilename.text

                        #relevant_table_links.append(report_info_df.tolist() + [page_10_K_url, table_name, table_url])
                        relevant_table_links.loc[report_info_df['Ticker'], report_info_df['10-K Report Date'].split('-')[0]] += table_url + ' | '
                        
                        print(page_10_K_url)
                        print(table_name)
                        print(table_url)
                        print('-'*100)
                        
            except:
                # some .xlm summary have acquisition related report but not .htm instance
                try:
                    page_10_K_url = get_10_K_page_url(xml_summary)
                    txt_url = get_10_K_txt(xml_summary)
                    reports_url = get_info_from_txt(txt_url, name=report_info_df['Ticker']+'_'+report_info_df['10-K Report Date'])

                    # of form [report name, report url]
                    for report_name_and_url in reports_url:
                        
                        #relevant_table_links.append(report_info_df.tolist() + [page_10_K_url] + report_url)
                        relevant_table_links.loc[report_info_df['Ticker'], report_info_df['10-K Report Date'].split('-')[0]] += report_name_and_url[1] + ' | '
                        

                        print(page_10_K_url)
                        print(report_name_and_url[0])
                        print(report_name_and_url[1])
                        print('-'*100)

                # real issue didnt catch
                except:
                    print('got fucked 2!')
                    failures += 1
                    failed_table_links.append([report_info_df['Ticker'], report_info_df['10-K Report Date'], get_10_K_txt(xml_summary)])
                    continue

                
    #relevant_table_links = pd.DataFrame(relevant_table_links, columns=['Company Name', 'Ticker', 'CIK', 'Sector', 
    #                                                                   '10-K Report Number', '10-K Report Date', 
    #                                                                   '10-K SEC Page', 'Table Name', 'Table Link'])
    #relevant_table_links = relevant_table_links.drop(columns=['CIK', 'Sector', '10-K Report Number'])
    
    failed_table_links = pd.DataFrame(failed_table_links, columns=['Ticker', '10-K Report Date', '10-K Report URL'])

    return relevant_table_links, failed_table_links, failures

# %%
relevant_table_links, failed_tables, failed_count = find_relevent_reports(firms_info)
# Out:
# 0
# QUMU
# 2020-03-06
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248220000007/FilingSummary.xml
# 1
# QUMU
# 2019-03-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248219000013/FilingSummary.xml
# 2
# QUMU
# 2018-03-23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248218000015/FilingSummary.xml
# 3
# QUMU
# 2017-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248217000024/FilingSummary.xml
# 4
# QUMU
# 2016-03-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-16-000029-index.htm
# Acquisition of Kulu Valley, Ltd
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R9.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-16-000029-index.htm
# Acquisition of Kulu Valley, Ltd (Tables)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R24.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-16-000029-index.htm
# Acquisition of Kulu Valley, Ltd Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R37.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-16-000029-index.htm
# Acquisition of Kulu Valley, Ltd Preliminary Purchase Accounting Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R38.htm
# ----------------------------------------------------------------------------------------------------
# 5
# QUMU
# 2015-03-24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248215000003/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-15-000003-index.htm
# Acquisition of Kulu Valley, Ltd
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248215000003/R10.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-15-000003-index.htm
# Acquisition of Kulu Valley, Ltd (Tables)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248215000003/R27.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-15-000003-index.htm
# Acquisition of Kulu Valley, Ltd Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248215000003/R42.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-15-000003-index.htm
# Acquisition of Kulu Valley, Ltd Preliminary Purchase Accounting Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248215000003/R43.htm
# ----------------------------------------------------------------------------------------------------
# 6
# QUMU
# 2014-03-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-14-000003-index.htm
# Acquisition Of Qumu, Inc.
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/R9.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-14-000003-index.htm
# Acquisition Of Qumu, Inc. (Tables)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/R30.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-14-000003-index.htm
# Acquisition Of Qumu, Inc. Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/R45.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-14-000003-index.htm
# Acquisition Of Qumu, Inc. Preliminary Purchase Accounting Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/R46.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000892482-14-000003-index.htm
# Acquisition Of Qumu, Inc. Pro Forma Operating Results (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000089248214000003/R47.htm
# ----------------------------------------------------------------------------------------------------
# 7
# QUMU
# 2013-03-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000892482/0001445305-13-000625-index.htm
# Acquisition Of Qumu, Inc.
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/R9.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0001445305-13-000625-index.htm
# Acquisition Of Qumu, Inc. (Tables)
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/R31.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0001445305-13-000625-index.htm
# Acquisition Of Qumu, Inc. Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/R47.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0001445305-13-000625-index.htm
# Acquisition Of Qumu, Inc. Preliminary Purchase Accounting Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/R48.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0001445305-13-000625-index.htm
# Acquisition Of Qumu, Inc. Pro Forma Operating Results (Details)
# https://www.sec.gov/Archives/edgar/data/0000892482/000144530513000625/R49.htm
# ----------------------------------------------------------------------------------------------------
# 8
# QUMU
# 2012-03-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710112000447/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-12-000447-index.htm
# Acquisition Of Qumu, Inc.
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710112000447/R9.htm
# ----------------------------------------------------------------------------------------------------
# 9
# QUMU
# 2011-03-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710111000403/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-11-000403-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2011-03-14_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-11-000403-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2011-03-14_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-11-000403-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2011-03-14_report_2.html
# ----------------------------------------------------------------------------------------------------
# 10
# QUMU
# 2010-03-12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710110000537/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-10-000537-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2010-03-12_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-10-000537-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2010-03-12_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-10-000537-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2010-03-12_report_2.html
# ----------------------------------------------------------------------------------------------------
# 11
# QUMU
# 2009-03-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710109000532/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-09-000532-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2009-03-16_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-09-000532-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2009-03-16_report_1.html
# ----------------------------------------------------------------------------------------------------
# 12
# QUMU
# 2008-03-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710108000645/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-08-000645-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2008-03-14_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-08-000645-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2008-03-14_report_1.html
# ----------------------------------------------------------------------------------------------------
# 13
# QUMU
# 2007-03-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710107000600/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-07-000600-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2007-03-16_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-07-000600-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2007-03-16_report_1.html
# ----------------------------------------------------------------------------------------------------
# 14
# QUMU
# 2006-03-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710106000590/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-06-000590-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2006-03-15_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-06-000590-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2006-03-15_report_1.html
# ----------------------------------------------------------------------------------------------------
# 15
# QUMU
# 2005-03-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710105000732/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-05-000732-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2005-03-16_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/0000897101-05-000732-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\QUMU_2005-03-16_report_1.html
# ----------------------------------------------------------------------------------------------------
# 16
# QUMU
# 2004-03-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710104000630/FilingSummary.xml
# Directly parse .txt html file
# 17
# QUMU
# 2003-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710103000252/FilingSummary.xml
# Directly parse .txt html file
# 18
# QUMU
# 2002-04-01
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710102000226/FilingSummary.xml
# Directly parse .txt html file
# 19
# QUMU
# 2001-04-02
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710101500098/FilingSummary.xml
# Directly parse .txt html file
# 20
# QUMU
# 2000-03-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710100000314/FilingSummary.xml
# Directly parse .txt html file
# 21
# QUMU
# 1999-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710199000315/FilingSummary.xml
# Directly parse .txt html file
# 22
# QUMU
# 1998-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710198000376/FilingSummary.xml
# Directly parse .txt html file
# 23
# QUMU
# 1997-04-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000892482/000089710197000439/FilingSummary.xml
# Directly parse .txt html file
# 24
# MICT
# 2020-02-19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000121390020004258/FilingSummary.xml
# 25
# MICT
# 2019-04-01
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000121390019005352/FilingSummary.xml
# 26
# MICT
# 2018-04-13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000121390018004398/FilingSummary.xml
# 27
# MICT
# 2017-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000121390017003070/FilingSummary.xml
# 28
# MICT
# 2016-04-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891316005073/FilingSummary.xml
# 29
# MICT
# 2015-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891315001100/FilingSummary.xml
# 30
# MICT
# 2014-03-19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891314000982/FilingSummary.xml
# 31
# MICT
# 2013-03-29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891313000945/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000854800/0001178913-13-000945-index.htm
# ACQUISITION OF NON-CONTROLLING INTEREST
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891313000945/R10.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/0001178913-13-000945-index.htm
# ACQUISITION OF NON-CONTROLLING INTEREST (Details)
# https://www.sec.gov/Archives/edgar/data/0000854800/000117891313000945/R46.htm
# ----------------------------------------------------------------------------------------------------
# 32
# MICT
# 2012-03-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000114420412018189/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000854800/0001144204-12-018189-index.htm
# ACQUISITION OF NON-CONTROLLING INTEREST
# https://www.sec.gov/Archives/edgar/data/0000854800/000114420412018189/R9.htm
# ----------------------------------------------------------------------------------------------------
# 33
# MICT
# 2011-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000114420411019079/FilingSummary.xml
# Directly parse .txt html file
# 34
# MICT
# 2010-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000114420410017083/FilingSummary.xml
# Directly parse .txt html file
# 35
# MICT
# 2009-03-31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000854800/000114420409017447/FilingSummary.xml
# Directly parse .txt html file
# 36
# ATVI
# 2020-02-27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000071887720000003/FilingSummary.xml
# 37
# ATVI
# 2019-02-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-19-000788-index.htm
# Acquisitions
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/R31.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-19-000788-index.htm
# Acquisitions (Tables)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/R53.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-19-000788-index.htm
# Acquisitions - Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/R106.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-19-000788-index.htm
# Acquisitions - Purchase Price Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/R107.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-19-000788-index.htm
# Acquisitions - Pro Forma Information (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746919000788/R108.htm
# ----------------------------------------------------------------------------------------------------
# 38
# ATVI
# 2018-02-27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-18-001114-index.htm
# Acquisitions
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/R28.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-18-001114-index.htm
# Acquisitions (Tables)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/R48.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-18-001114-index.htm
# Acquisitions - Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/R92.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-18-001114-index.htm
# Acquisitions - Purchase Price Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/R93.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-18-001114-index.htm
# Acquisitions - Pro Forma Information (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746918001114/R94.htm
# ----------------------------------------------------------------------------------------------------
# 39
# ATVI
# 2017-02-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R29.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions (Tables)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R49.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions - Narrative (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R92.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions - Purchase Price Composition (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R93.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions - Preliminary Purchase Price Allocation (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R94.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-17-001072-index.htm
# Acquisitions - Pro Forma Information (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746917001072/R95.htm
# ----------------------------------------------------------------------------------------------------
# 40
# ATVI
# 2016-02-29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746916010584/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-16-010584-index.htm
# Acquisitions
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746916010584/R31.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-16-010584-index.htm
# Acquisitions (Tables)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746916010584/R51.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-16-010584-index.htm
# Acquisitions (Details)
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746916010584/R93.htm
# ----------------------------------------------------------------------------------------------------
# 41
# ATVI
# 2015-02-26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746915001298/FilingSummary.xml
# 42
# ATVI
# 2014-03-03
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746914001688/FilingSummary.xml
# 43
# ATVI
# 2013-02-22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746913001506/FilingSummary.xml
# 44
# ATVI
# 2012-02-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746912001775/FilingSummary.xml
# 45
# ATVI
# 2011-02-25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746911001413/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-11-001413-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2011-02-25_report_0.html
# ----------------------------------------------------------------------------------------------------
# 46
# ATVI
# 2010-03-01
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746910001649/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-10-001649-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2010-03-01_report_0.html
# ----------------------------------------------------------------------------------------------------
# 47
# ATVI
# 2009-02-27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746909002015/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-09-002015-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2009-02-27_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-09-002015-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2009-02-27_report_1.html
# ----------------------------------------------------------------------------------------------------
# 48
# ATVI
# 2008-05-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746908007085/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-08-007085-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2008-05-30_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001047469-08-007085-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2008-05-30_report_1.html
# ----------------------------------------------------------------------------------------------------
# 49
# ATVI
# 2007-06-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000110465907047752/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-07-047752-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2007-06-14_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-07-047752-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2007-06-14_report_1.html
# ----------------------------------------------------------------------------------------------------
# 50
# ATVI
# 2006-06-09
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000110465906040913/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-06-040913-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2006-06-09_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-06-040913-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2006-06-09_report_1.html
# ----------------------------------------------------------------------------------------------------
# 51
# ATVI
# 2005-06-09
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000110465905027535/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-05-027535-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2005-06-09_report_0.html
# ----------------------------------------------------------------------------------------------------
# 52
# ATVI
# 2004-06-10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000110465904016641/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-04-016641-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2004-06-10_report_0.html
# ----------------------------------------------------------------------------------------------------
# 53
# ATVI
# 2003-06-19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000110465903012724/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0001104659-03-012724-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2003-06-19_report_0.html
# ----------------------------------------------------------------------------------------------------
# 54
# ATVI
# 2002-06-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000091205702025821/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-02-025821-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2002-06-28_report_0.html
# ----------------------------------------------------------------------------------------------------
# 55
# ATVI
# 2001-06-27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000091205701521517/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-01-521517-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2001-06-27_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-01-521517-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2001-06-27_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-01-521517-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2001-06-27_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-01-521517-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2001-06-27_report_3.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/0000912057-01-521517-index.htm
# report 4
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\ATVI_2001-06-27_report_4.html
# ----------------------------------------------------------------------------------------------------
# 56
# ATVI
# 2000-06-29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000091205700030433/FilingSummary.xml
# Directly parse .txt html file
# 57
# ATVI
# 1999-06-29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746999025826/FilingSummary.xml
# Directly parse .txt html file
# 58
# ATVI
# 1998-06-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000104746998024188/FilingSummary.xml
# Directly parse .txt html file
# 59
# ATVI
# 1997-06-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000091205797020468/FilingSummary.xml
# Directly parse .txt html file
# 60
# ATVI
# 1996-07-08
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000071887796000011/FilingSummary.xml
# Directly parse .txt html file
# 61
# ATVI
# 1995-06-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000718877/000071887795000005/FilingSummary.xml
# Directly parse .txt html file
# 62
# ESTC
# 2020-06-26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R12.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions (Tables)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R27.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions - Additional Information (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R44.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions - Summary of Components Purchase Price and Preliminary Allocation of Purchase Price at Fair Value (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R45.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions -Summary of Preliminary Estimated Fair Values of Assets Acquired and Liabilities Assumed (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R46.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions - Schedule of Components of Identifiable Intangible Assets Acquired and Estimated Useful Lives (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R47.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Acquisitions - Summary of Unaudited Pro Forma Condensed Consolidated Financial Information (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R48.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/0001628280-20-009982-index.htm
# Balance Sheet Components - Schedule of Activity of Deferred Contract Acquisition Costs (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000162828020009982/R61.htm
# ----------------------------------------------------------------------------------------------------
# 63
# ESTC
# 2019-06-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001707753/000156459019024066/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0001707753/0001564590-19-024066-index.htm
# Balance Sheet Components - Schedule of Activity of Deferred Contract Acquisition Costs (Details)
# https://www.sec.gov/Archives/edgar/data/0001707753/000156459019024066/R59.htm
# ----------------------------------------------------------------------------------------------------
# 64
# AVNW
# 2019-08-27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778919000061/FilingSummary.xml
# 65
# AVNW
# 2018-08-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778918000061/FilingSummary.xml
# 66
# AVNW
# 2017-09-06
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778917000044/FilingSummary.xml
# 67
# AVNW
# 2016-09-09
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778916000172/FilingSummary.xml
# 68
# AVNW
# 2015-10-01
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778915000072/FilingSummary.xml
# 69
# AVNW
# 2014-12-22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778914000086/FilingSummary.xml
# 70
# AVNW
# 2013-09-23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778913000057/FilingSummary.xml
# 71
# AVNW
# 2012-09-04
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778912000023/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0001377789/0001377789-12-000023-index.htm
# Acquisition and Divestitures
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778912000023/R8.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001377789-12-000023-index.htm
# Acquisitions and Divestitures (Tables)
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778912000023/R24.htm
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001377789-12-000023-index.htm
# Acquisitions and Divestitures (Details)
# https://www.sec.gov/Archives/edgar/data/0001377789/000137778912000023/R37.htm
# ----------------------------------------------------------------------------------------------------
# 72
# AVNW
# 2011-09-12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000119312511245965/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_3.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 4
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_4.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 5
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_5.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 6
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_6.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 7
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_7.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0001193125-11-245965-index.htm
# report 8
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2011-09-12_report_8.html
# ----------------------------------------------------------------------------------------------------
# 73
# AVNW
# 2010-09-09
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/000095012310084926/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2010-09-09_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2010-09-09_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2010-09-09_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2010-09-09_report_3.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 4
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\AVNW_2010-09-09_report_4.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0001377789/0000950123-10-084926-index.htm
# report 5
# ...
# https://www.sec.gov/Archives/edgar/data/0000278166/000095012311056537/FilingSummary.xml
# Directly parse .txt html file
# 502
# CVCO
# 2010-05-21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095012310052053/FilingSummary.xml
# Directly parse .txt html file
# 503
# CVCO
# 2009-05-21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000136231009008044/FilingSummary.xml
# Directly parse .txt html file
# 504
# CVCO
# 2008-05-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015308001062/FilingSummary.xml
# Directly parse .txt html file
# 505
# CVCO
# 2007-05-22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015307001202/FilingSummary.xml
# Directly parse .txt html file
# 506
# CVCO
# 2006-05-24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015306001486/FilingSummary.xml
# Directly parse .txt html file
# 507
# CVCO
# 2005-05-20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015305001194/FilingSummary.xml
# Directly parse .txt html file
# 508
# CVCO
# 2004-05-24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015304001296/FilingSummary.xml
# Directly parse .txt html file
# 509
# CVCO
# 1996-12-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015396001102/FilingSummary.xml
# Directly parse .txt html file
# 510
# CVCO
# 1995-12-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000278166/000095015395000435/FilingSummary.xml
# Directly parse .txt html file
# 511
# LAKE
# 2020-04-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000165495420004107/FilingSummary.xml
# 512
# LAKE
# 2019-04-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000165495419004479/FilingSummary.xml
# 513
# LAKE
# 2018-04-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420418020717/FilingSummary.xml
# 514
# LAKE
# 2017-04-26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420417022256/FilingSummary.xml
# 515
# LAKE
# 2016-04-21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420416095568/FilingSummary.xml
# 516
# LAKE
# 2015-05-18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420415032060/FilingSummary.xml
# 517
# LAKE
# 2014-04-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420414025258/FilingSummary.xml
# 518
# LAKE
# 2013-05-21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420413030790/FilingSummary.xml
# 519
# LAKE
# 2012-04-18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420412022494/FilingSummary.xml
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-12-022494-index.htm
# BUSINESS COMBINATIONS-Acquisition of Qualytextil, S.A.
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420412022494/R12.htm
# ----------------------------------------------------------------------------------------------------
# 520
# LAKE
# 2011-04-07
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420411020736/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-11-020736-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2011-04-07_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-11-020736-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2011-04-07_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-11-020736-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2011-04-07_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-11-020736-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2011-04-07_report_3.html
# ----------------------------------------------------------------------------------------------------
# 521
# LAKE
# 2010-04-16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000114420410020709/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_3.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 4
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_4.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0001144204-10-020709-index.htm
# report 5
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2010-04-16_report_5.html
# ----------------------------------------------------------------------------------------------------
# 522
# LAKE
# 2009-04-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431709000925/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_1.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 2
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_2.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 3
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_3.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 4
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_4.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 5
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_5.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 6
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_6.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 7
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_7.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 8
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_8.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 9
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_9.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 10
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_10.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-09-000925-index.htm
# report 11
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2009-04-15_report_11.html
# ----------------------------------------------------------------------------------------------------
# 523
# LAKE
# 2008-04-14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431708001046/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-08-001046-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2008-04-14_report_0.html
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-08-001046-index.htm
# report 1
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2008-04-14_report_1.html
# ----------------------------------------------------------------------------------------------------
# 524
# LAKE
# 2007-04-12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431707001003/FilingSummary.xml
# Directly parse .txt html file
# https://www.sec.gov/Archives/edgar/data/0000798081/0000914317-07-001003-index.htm
# report 0
# file:///C:\Users\happy\OneDrive - California Institute of Technology\Desktop\sec_data\LAKE_2007-04-12_report_0.html
# ----------------------------------------------------------------------------------------------------
# 525
# LAKE
# 2006-04-17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431706001087/FilingSummary.xml
# Directly parse .txt html file
# 526
# LAKE
# 2005-04-15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431705001282/FilingSummary.xml
# Directly parse .txt html file
# 527
# LAKE
# 2004-04-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431704001806/FilingSummary.xml
# Directly parse .txt html file
# 528
# LAKE
# 2003-04-29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431703001373/FilingSummary.xml
# Directly parse .txt html file
# 529
# LAKE
# 2002-05-01
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431702000483/FilingSummary.xml
# Directly parse .txt html file
# 530
# LAKE
# 2001-04-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431701500037/FilingSummary.xml
# Directly parse .txt html file
# 531
# LAKE
# 2000-04-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431700000318/FilingSummary.xml
# Directly parse .txt html file
# 532
# LAKE
# 1999-04-28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431799000249/FilingSummary.xml
# Directly parse .txt html file
# 533
# LAKE
# 1998-04-30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000091431798000281/FilingSummary.xml
# Directly parse .txt html file
# 534
# LAKE
# 1997-04-25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000088981297001039/FilingSummary.xml
# Directly parse .txt html file
# 535
# LAKE
# 1996-04-26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/0000798081/000088981296000382/FilingSummary.xml
# Directly parse .txt html file

# %%
print('Unable to process', failed_count, '10-Ks in total.')
# Out:
# Unable to process 16 10-Ks in total.

# %%
failed_tables
# Out:
#    Ticker 10-K Report Date                                    10-K Report URL
# 0     WGO       2010-10-26  https://www.sec.gov/Archives/edgar/data/000010...
# 1     MOH       2011-03-08  https://www.sec.gov/Archives/edgar/data/000117...
# 2     MOH       2010-03-16  https://www.sec.gov/Archives/edgar/data/000117...
# 3     MOH       2008-03-17  https://www.sec.gov/Archives/edgar/data/000117...
# 4     CSU       2007-03-16  https://www.sec.gov/Archives/edgar/data/000104...
# 5     CSU       2004-03-29  https://www.sec.gov/Archives/edgar/data/000104...
# 6     SEM       2011-03-09  https://www.sec.gov/Archives/edgar/data/000132...
# 7     SEM       2010-03-17  https://www.sec.gov/Archives/edgar/data/000132...
# 8     NRP       2011-02-28  https://www.sec.gov/Archives/edgar/data/000117...
# 9     NRP       2010-02-26  https://www.sec.gov/Archives/edgar/data/000117...
# 10    NRP       2008-02-29  https://www.sec.gov/Archives/edgar/data/000117...
# 11    NRP       2007-02-28  https://www.sec.gov/Archives/edgar/data/000117...
# 12    NRP       2006-02-27  https://www.sec.gov/Archives/edgar/data/000117...
# 13    NRP       2004-03-04  https://www.sec.gov/Archives/edgar/data/000117...
# 14    HES       2007-03-01  https://www.sec.gov/Archives/edgar/data/000000...
# 15    SLB       2011-02-04  https://www.sec.gov/Archives/edgar/data/000008...

# %%
relevant_table_links
# Out:
#                                                     2020  \
# QUMU
# MICT
# ATVI
# ESTC    https://www.sec.gov/Archives/edgar/data/00017...
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB     https://www.sec.gov/Archives/edgar/data/00012...
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP
# FTSI
# CHX     https://www.sec.gov/Archives/edgar/data/00017...
# HES
# SLB
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO    https://www.sec.gov/Archives/edgar/data/00002...
# LAKE
#
#                                                     2019  \
# QUMU
# MICT
# ATVI    https://www.sec.gov/Archives/edgar/data/00007...
# ESTC    https://www.sec.gov/Archives/edgar/data/00017...
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB     https://www.sec.gov/Archives/edgar/data/00012...
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP
# FTSI
# CHX     https://www.sec.gov/Archives/edgar/data/00017...
# HES
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH    file:///C:\Users\happy\OneDrive - California ...
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP     https://www.sec.gov/Archives/edgar/data/00012...
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO
# LAKE
#
#                                                     2018  \
# QUMU
# MICT
# ATVI    https://www.sec.gov/Archives/edgar/data/00007...
# ESTC
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB     https://www.sec.gov/Archives/edgar/data/00012...
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP
# FTSI    file:///C:\Users\happy\OneDrive - California ...
# CHX
# HES
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP     https://www.sec.gov/Archives/edgar/data/00012...
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO
# LAKE
#
#                                                     2017  \
# QUMU
# MICT
# ATVI    https://www.sec.gov/Archives/edgar/data/00007...
# ESTC
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB     https://www.sec.gov/Archives/edgar/data/00012...
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP     https://www.sec.gov/Archives/edgar/data/00012...
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO
# LAKE
#
#                                                     2016  \
# QUMU    https://www.sec.gov/Archives/edgar/data/00008...
# MICT
# ATVI    https://www.sec.gov/Archives/edgar/data/00007...
# ESTC
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB
# CNTY
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP
# HWKN
# HYMC
# PEIX    file:///C:\Users\happy\OneDrive - California ...
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO    https://www.sec.gov/Archives/edgar/data/00002...
# LAKE
#
#                                                     2015  \
# QUMU    https://www.sec.gov/Archives/edgar/data/00008...
# MICT
# ATVI
# ESTC
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP     https://www.sec.gov/Archives/edgar/data/00012...
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH     https://www.sec.gov/Archives/edgar/data/00008...
# CVCO
# LAKE
#
#                                                     2014  \
# QUMU    https://www.sec.gov/Archives/edgar/data/00008...
# MICT
# ATVI
# ESTC
# AVNW
# XSPA
# WGO
# HSKA    https://www.sec.gov/Archives/edgar/data/00010...
# TPB
# CNTY    https://www.sec.gov/Archives/edgar/data/00009...
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES     https://www.sec.gov/Archives/edgar/data/00000...
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH
# CVCO
# LAKE
#
#                                                     2013  \
# QUMU    https://www.sec.gov/Archives/edgar/data/00008...
# MICT    https://www.sec.gov/Archives/edgar/data/00008...
# ATVI
# ESTC
# AVNW
# XSPA    https://www.sec.gov/Archives/edgar/data/00014...
# WGO     https://www.sec.gov/Archives/edgar/data/00001...
# HSKA
# TPB
# CNTY
# MOH
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES     https://www.sec.gov/Archives/edgar/data/00000...
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH
# CVCO
# LAKE
#
#                                                     2012  \
# QUMU    https://www.sec.gov/Archives/edgar/data/00008...
# MICT    https://www.sec.gov/Archives/edgar/data/00008...
# ATVI
# ESTC
# AVNW    https://www.sec.gov/Archives/edgar/data/00013...
# XSPA
# WGO     https://www.sec.gov/Archives/edgar/data/00001...
# HSKA
# TPB
# CNTY    file:///C:\Users\happy\OneDrive - California ...
# MOH     file:///C:\Users\happy\OneDrive - California ...
# CSU     https://www.sec.gov/Archives/edgar/data/00010...
# AKBA
# SEM     https://www.sec.gov/Archives/edgar/data/00013...
# BPMC
# NRP     https://www.sec.gov/Archives/edgar/data/00011...
# FTSI
# CHX
# HES     https://www.sec.gov/Archives/edgar/data/00000...
# SLB     https://www.sec.gov/Archives/edgar/data/00000...
# ENV     https://www.sec.gov/Archives/edgar/data/00013...
# LEGH
# PBT
# MARPS
# NRT
# CE      https://www.sec.gov/Archives/edgar/data/00013...
# CMP     https://www.sec.gov/Archives/edgar/data/00012...
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH
# CVCO    https://www.sec.gov/Archives/edgar/data/00002...
# LAKE    https://www.sec.gov/Archives/edgar/data/00007...
#
#                                                     2011  ... 1959 1958 1957  \
# QUMU    file:///C:\Users\happy\OneDrive - California ...  ...
# MICT                                                      ...
# ATVI    file:///C:\Users\happy\OneDrive - California ...  ...
# ESTC                                                      ...
# AVNW    file:///C:\Users\happy\OneDrive - California ...  ...
# XSPA    file:///C:\Users\happy\OneDrive - California ...  ...
# WGO     file:///C:\Users\happy\OneDrive - California ...  ...
# HSKA                                                      ...
# TPB                                                       ...
# CNTY    file:///C:\Users\happy\OneDrive - California ...  ...
# MOH                                                       ...
# CSU     file:///C:\Users\happy\OneDrive - California ...  ...
# AKBA                                                      ...
# SEM                                                       ...
# BPMC                                                      ...
# NRP                                                       ...
# FTSI                                                      ...
# CHX                                                       ...
# HES     file:///C:\Users\happy\OneDrive - California ...  ...
# SLB                                                       ...
# ENV     file:///C:\Users\happy\OneDrive - California ...  ...
# LEGH                                                      ...
# PBT                                                       ...
# MARPS                                                     ...
# NRT                                                       ...
# CE      file:///C:\Users\happy\OneDrive - California ...  ...
# CMP                                                       ...
# HWKN    file:///C:\Users\happy\OneDrive - California ...  ...
# HYMC                                                      ...
# PEIX    file:///C:\Users\happy\OneDrive - California ...  ...
# WRTC                                                      ...
# RDVT                                                      ...
# MTH     file:///C:\Users\happy\OneDrive - California ...  ...
# CVCO                                                      ...
# LAKE    file:///C:\Users\happy\OneDrive - California ...  ...
#
#       1956 1955 1954 1953 1952 1951 1950
# QUMU
# MICT
# ATVI
# ESTC
# AVNW
# XSPA
# WGO
# HSKA
# TPB
# CNTY
# MOH
# CSU
# AKBA
# SEM
# BPMC
# NRP
# FTSI
# CHX
# HES
# SLB
# ENV
# LEGH
# PBT
# MARPS
# NRT
# CE
# CMP
# HWKN
# HYMC
# PEIX
# WRTC
# RDVT
# MTH
# CVCO
# LAKE
#
# [35 rows x 71 columns]

# %%
relevant_table_links.loc['QUMU','2016']
# Out:
# ' https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R9.htm | https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R24.htm | https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R37.htm | https://www.sec.gov/Archives/edgar/data/0000892482/000089248216000029/R38.htm | '

# %%
# save file for RA
relevant_table_links.to_csv('reports_links_for_selected_firms.csv')
failed_tables.to_csv('failed_to_parse_for_selected_firms.csv')

# %%
################################

# %%
# some checking
relative_fp = os.path.realpath(os.getcwd())
fp = relative_fp + 'reports_links_for_selected_firms.csv'
report_names = pd.read_csv('reports_links_for_selected_firms.csv')['Ticker']

# %%
report_names
# Out:
# 0       QUMU
# 1       QUMU
# 2       QUMU
# 3       QUMU
# 4       QUMU
#         ...
# 1167    LAKE
# 1168    LAKE
# 1169    LAKE
# 1170    LAKE
# 1171    LAKE
# Name: Ticker, Length: 1172, dtype: object

# %%
names = pd.read_csv('company basic info')['Ticker']
for name in names: 
    #print(name)
    if name not in list(report_names):
        print(name)
        
# AKBA new firm since 2018, no acq
# BPMC new firm since 2016, no acq
# PBT firm since 1996, checked .txt 10K no acq
# MARPS firm since 1995, checked .txt 10K no acq
# NRT firm since 1996, checked .txt 10K no acq
# HYMC new firm since 2019, no acq
# WRTC new firm since 2018, no acq
# RDVT new firm since 2019, no acq
# Out:
# AKBA
# BPMC
# PBT
# MARPS
# NRT
# HYMC
# WRTC
# RDVT

# %% [markdown]
# ***
# ## Grab the Filing XML Summary
# Something that makes 10-K and for that matter 10-Q filings so unique is we have access to a particular document that gives us a quick way to grab the data we need from a 10-K. This file is the **filing summary** and comes in an either an `XML` or `xlsx` format. While you would think these two files would be identical, they are not, the `XML` version of the file provides us with a quick way to see the structure of the 10-K, defines whether a section is a note, table or details, and the name and each corresponding file for each section.
#
# The `xlsx` file, on the other hand, contains each section of the 10K in an excel style format. This file can come in handy if we want to parse just a single location, but be warned that formatting issues will not make it a simple load.
#
# Let's assume we want to parse the `XML` file as we want to leverage the underlying structure of the 10-K report. In the section below, I outline how you would go about this process and use a sample document URL for our demonstration.

# %%
# define the base url needed to create the file url.
base_url = r"https://www.sec.gov"

# convert a normal url to a document url
normal_url = r"https://www.sec.gov/Archives/edgar/data/50863/0000050863-20-000011.txt"

# define a url that leads to a 10k document landing page
documents_url = normal_url.replace('-','').replace('.txt','/index.json')

# request the url and decode it.
content = requests.get(documents_url).json()

for file in content['directory']['item']:
    
    # Grab the filing summary and create a new url leading to the file so we can download it.
    if file['name'] == 'FilingSummary.xml':

        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
        
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/50863/000005086320000011/FilingSummary.xml

# %% [markdown]
# ***
# ## Parsing the Filing Summary
# Okay, we now have access to a filing summary file. The first thing we need to do is request the file using the `requests` library we will then take the contents of that request and pass through our `BeautifulSoup` object. I encourage individuals who are new to this process to look at the file itself, so you better understanding of the structure, this will reinforce my approach below.
#
# The main section of the file we want to grab belongs under the `myreports` tag. This contains a list of each of the reports in the document. Each report falls under a `report` tag and has the following structure:
#
# `<Report instance="mtii-20181231.xml">
#     <IsDefault>false</IsDefault>
#     <HasEmbeddedReports>false</HasEmbeddedReports>
#     <HtmlFileName>R1.htm</HtmlFileName>
#     <LongName>0001000 - Document - Document and Entity Information</LongName>
#     <ReportType>Sheet</ReportType>
#     <Role>http://www.monitronics.com/role/DocumentAndEntityInformation</Role>
#     <ShortName>Document and Entity Information</ShortName>
#     <MenuCategory>Cover</MenuCategory>
#     <Position>1</Position>
# </Report>`
#
# The main tags we will be concerned with are the following:
#
# 1. **`HtmlFileName`** - This is the name of the file and will be needed to build the file URL.
# 2. **`LongName`** - This is the long name of the report, with its ID. Keep in mind the ID can be leveraged in other 10Ks of other companies, but unfortunately, it is not always guaranteed.
# 3. **`ShortName`** - The short name of the report, this is surprisingly more consistent across companies compared to the long name which includes the ID.
# 4. **`MenuCategory`** - This can be thought of as a category the report falls under, a table, notes, details, cover, or statements. This will be leveraged as another filtering mechanism.
# 5. **`Position`** - This is the position of the report in the main document and also corresponds to the `HtmlFileName.`

# %%
company_xml_summaries = {'INTC': r'https://www.sec.gov/Archives/edgar/data/50863/000005086320000011/FilingSummary.xml', 
                         'GOOG': r'https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/FilingSummary.xml',
                         'AMZN': r'https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/FilingSummary.xml'}

# %%
def find_relevent_reports(xlm_summaries):
    #dict for relevant reports for each company
    company_reports = {}
    
    for company in company_xml_summaries.keys():
        xml_summary = company_xml_summaries[company]
    
        # define a new base url that represents the filing folder. This will come in handy when we need to download the reports.
        base_url = xml_summary.replace('FilingSummary.xml', '')

        # request and parse the content
        content = requests.get(xml_summary).content

        soup = BeautifulSoup(content, 'lxml')

        # find the 'myreports' tag because this contains all the individual reports submitted.
        reports = soup.find('myreports')

        # I want a list to store all the individual components of the report, so create the master list.
        master_reports = []

        # for aquisition related reports#############
        acquisition_reports = []

        # loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
        for report in reports.find_all('report')[:-1]:

            # let's create a dictionary to store all the different parts we need.
            report_dict = {}
            report_dict['name_short'] = report.shortname.text
            report_dict['name_long'] = report.longname.text
            report_dict['position'] = report.position.text
            report_dict['category'] = report.menucategory.text
            report_dict['url'] = base_url + report.htmlfilename.text

            # append the dictionary to the master list.
            master_reports.append(report_dict)

            # acquisition related
            #what we want
            if 'acquisition' in report.shortname.text.lower() or 'aquisition' in report.longname.text.lower():
                acquisition_reports.append(report_dict)

                # print the info to the user.
                #print('-'*100)
                print(company)
                print(base_url + report.htmlfilename.text)
                print(report.longname.text)
                print(report.shortname.text)
                print(report.menucategory.text)
                print(report.position.text)
            
        company_reports[company] = acquisition_reports

    return company_reports

# %%
company_relevent_reports = find_relevent_reports(company_xml_summaries)
# Out:
# INTC
# https://www.sec.gov/Archives/edgar/data/50863/000005086320000011/R19.htm
# 2112100 - Disclosure - Acquisitions & Divestitures
# Acquisitions & Divestitures
# Notes
# 19
# INTC
# https://www.sec.gov/Archives/edgar/data/50863/000005086320000011/R67.htm
# 2412401 - Disclosure - Acquisitions (Details)
# Acquisitions (Details)
# Details
# 67
# GOOG
# https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/R16.htm
# 2111100 - Disclosure - Acquisitions
# Acquisitions
# Notes
# 16
# GOOG
# https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/R65.htm
# 2411401 - Disclosure - Acquisitions (Narrative) (Details)
# Acquisitions (Narrative) (Details)
# Details
# 65
# GOOG
# https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/R67.htm
# 2412403 - Disclosure - Goodwill and Other Intangible Assets (Acquisition-Related Intangible Assets that are being Amortized) (Details)
# Goodwill and Other Intangible Assets (Acquisition-Related Intangible Assets that are being Amortized) (Details)
# Details
# 67
# GOOG
# https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/R69.htm
# 2412405 - Disclosure - Goodwill and Other Intangible Assets (Expected Amortization Expense for Acquisition-Related Intangible Assets) (Details)
# Goodwill and Other Intangible Assets (Expected Amortization Expense for Acquisition-Related Intangible Assets) (Details)
# Details
# 69
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R13.htm
# 2105100 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets
# Acquisitions, Goodwill, and Acquired Intangible Assets
# Notes
# 13
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R26.htm
# 2305301 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets (Tables)
# Acquisitions, Goodwill, and Acquired Intangible Assets (Tables)
# Tables
# 26
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R60.htm
# 2405402 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets - Additional Information (Details)
# Acquisitions, Goodwill, and Acquired Intangible Assets - Additional Information (Details)
# Details
# 60
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R61.htm
# 2405403 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets - Allocation of Aggregate Purchase Price of Acquisitions (Details)
# Acquisitions, Goodwill, and Acquired Intangible Assets - Allocation of Aggregate Purchase Price of Acquisitions (Details)
# Details
# 61
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R62.htm
# 2405404 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets - Summary of Goodwill Activity by Segment (Details)
# Acquisitions, Goodwill, and Acquired Intangible Assets - Summary of Goodwill Activity by Segment (Details)
# Details
# 62
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R63.htm
# 2405405 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets - Acquired Intangible Assets (Details)
# Acquisitions, Goodwill, and Acquired Intangible Assets - Acquired Intangible Assets (Details)
# Details
# 63
# AMZN
# https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004/R64.htm
# 2405406 - Disclosure - Acquisitions, Goodwill, and Acquired Intangible Assets - Expected Future Amortization Expense of Acquired Intangible Assets (Details)
# Acquisitions, Goodwill, and Acquired Intangible Assets - Expected Future Amortization Expense of Acquired Intangible Assets (Details)
# Details
# 64

# %%
# function to help find words related to acquisition and number and cost, and n words before and after them
def extract_info(lst, n_words=16):
    # a set for the indexes to pull out the important words
    info_indexes = set()
    
    acquisition_related_words = ['acquire', 'acquisition']
    numbers = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']
    digits = [str(i) for i in range(1, 11)]
    dollar = ['$']
    numerical_keywords = numbers + digits + dollar
    
    for i in range(len(lst)):
        word = lst[i]
        
        # find if any word is a keyword of any variation
        if True in [keyword.lower() in word for keyword in acquisition_related_words]:

            # check if numbers or digits or dollars are n words adjacent
            front = lst[i-n_words : i+1]
            #for front
            for front_word in front: 
                if True in [keyword.lower() in front_word for keyword in numerical_keywords]: 
                    info_indexes.update([index for index in range(max(i-n_words, 0), i+1)])
            
            end = lst[i : i+n_words+1]
            #for end
            for end_word in end: 
                if True in [keyword.lower() in end_word for keyword in numerical_keywords]:
                    info_indexes.update([index for index in range(i, min(i+n_words+1, len(lst)))])   
            
        '''
        # find if any word is a keyword of any variation
        if True in [word in keyword.lower() for keyword in keywords]:
            # update set
            info_indexes.update([index for index in range(i-n_words, i+n_words+1)])
        '''
    
    return np.array(lst)[list(info_indexes)] # important words

# %%
def company_acquisition_info(company_relevent_reports):
    for company in company_relevent_reports.keys():
        # get report dictionaries for each company
        report_dicts = company_relevent_reports[company]
        has_info_on_acquisition = False

        for report_dict in report_dicts:
            # access each relevant report using url
            url = report_dict['url']
            content = requests.get(url).content
            soup = BeautifulSoup(content, 'html')

            for paragraph in soup.find_all('td',{'class':'text'}):
                words = paragraph.text.split()
                if words != []:
                    # only works for plain texts report, where each comapny should have a note section for acquisition
                    info = extract_info(words)
                    info 
                    info_string = ' '.join(info)
                    if info_string.strip() != '':
                        no_info_on_acquisition = True
                        print(company)
                        print(info_string)#.replace('.', '.\n'))
                        print()
                    

        #inform user if this 10-K does not disclose acquisition info for this firm
        if not no_info_on_acquisition:
            print('No acquisition information disclosed for ' + company)
    
    return

# %%
company_acquisition_info(company_relevent_reports)
# Out:
# INTC
# acquisitions in both 2019 and 2018, all of which qualified as business combinations. Except for the acquisition of Habana Labs, these acquisitions acquisitions in 2019 and 2018 primarily consisted of cash and was allocated to goodwill and identified intangible the classification of intangible assets, see "Note 13: Identified Intangible Assets."Habana LabsOn December 12, 2019, we acquired opportunity. Total consideration to acquire Habana Labs was $1.7 billion. The fair values of the assets acquired relate to goodwill of $1.5 billion and acquisition-related intangible assets of $250 million, which was primarily in-process research and development. The goodwill and operating of Habana Labs are included in our DCG operating segment.Goodwill of $1.5 billion arising from the acquisition
#
# GOOG
# acquisition of Looker, a unified platform for business intelligence, data applications and embedded analytics for $2.4 billion, measurement period. The $2.4 billion purchase price includes our previously held equity interest and excludes post acquisition compensation arrangements. In aggregate, $91 million was cash acquired, $290 million was attributed to intangible assets, $1.9 billion to goodwill and $48 million to net assets acquired. acquisition. Goodwill is not expected to be deductible for tax purposes.Other AcquisitionsDuring the year ended December 31, 2019, we completed other acquisitions and purchases of intangible assets for total consideration of approximately $1.0 billion. In aggregate, $28 million was cash acquired, $282 million was attributed to intangible assets, $904 million to goodwill and $185 million to net liabilities assumed. These acquisitions acquired and purchased during the year ended December 31, 2019, patents and developed technology have a weighted-average useful life of 4.5 years.Pending Acquisition of FitbitIn November 2019, we entered into an agreement to acquire Fitbit, a leading wearables brand, for $7.35 per share, representing a total purchase price of approximately $2.1 billion as of the date of the agreement. The acquisition of Fitbit is expected to be completed in 2020, subject to customary closing conditions, including the
#
# AMZN
# 2017, we acquired Souq Group Ltd., an e-commerce company, for approximately $583 million, net of cash acquired, and on August 28, 2017, we acquired Whole Foods Market, a grocery store chain, for approximately $13.2 billion, net of cash acquired. Both acquisitions are intended to expand our retail presence. During 2017, we also acquired certain other companies for an aggregate purchase price of $204 million. The primary reason for our other 2017 acquisitions was to acquire technologies and know-how to enable Amazon to serve customers more effectively.2018 Acquisition ActivityOn April 12, 2018, we acquired Ring Inc. (“Ring”) for cash consideration of approximately $839 million, net of cash acquired, and on September 11, 2018, we acquired PillPack, Inc. (“PillPack”) for cash consideration of approximately $753 million, net of cash acquired, to expand our product and service offerings. During 2018, we also acquired certain other companies for an aggregate purchase price of $57 million. The primary reason for our other 2018 acquisitions was to acquire technologies and know-how to enable Amazon to serve customers more effectively.2019 Acquisition Activity During 2019, we acquired certain companies for an aggregate purchase price of $315 million. The primary reason for these acquisitions, none of which were individually material to our consolidated financial statements, was to acquire technologies and not significant. Pro forma results of operations have not been presented because the effects of 2019 acquisitions, acquisitions was allocated as follows (in millions): December 31, 2017 2018 2019 Purchase Price Cash paid, net of cash acquired$13,859 $1,618 $276Indemnification holdback104 31 39 $13,963 $1,649 $315Allocation Goodwill$9,501 $1,228 $189Intangible assets (1): Marketing-related1,987 186 8Contract-based440 285 139Customer-related54 193 14 2,647 677 161Property and equipment3,810 11 3Deferred tax assets117 174 29Other assets acquired1,858 282 41Long-term debt(1,165) (176) (31)Deferred tax liabilities(961) (159) (34)Other liabilities assumed(1,844) (388) (43) $13,963 $1,649 $315 ___________________(1)Intangible assets acquired in 2017, 2018, and 2019 have estimated useful lives of between one and twenty-five years, two years, six years, and five years. We determined the estimated fair value of identifiable intangible assets acquired acquired companies is generally not deductible for tax purposes. The following summarizes our goodwill activity in 2018 2019 by segment (in millions): NorthAmerica International AWS ConsolidatedGoodwill - January 1, 2018$11,165 $1,108 $1,077 $13,350New acquisitions (1)1,031 177 20 1,228Other adjustments (2)(5) (15) (10) (30)Goodwill - December 31, 201812,191 1,270 1,087 14,548New acquisitions71 29 89 189Other adjustments (2)2 1 14 17Goodwill - December 31, 2019$12,264 $1,300 $1,190 $14,754 ___________________(1)Primarily includes the acquisitions of Ring and PillPack in the North America segment.(2)Primarily includes changes in foreign exchange rates.Intangible AssetsAcquired of fully-amortized intangibles.(2)Intangible assets have estimated useful lives of between one and twenty-five years.Amortization expense for acquired intangibles was $366 million, $475 million, and $565 million in 2017, 2018, and 2019. Expected future amortization expense of acquired intangible assets as of December 31, 2019 is as follows (in millions): Year Ended December 31,2020$4862021424202239120233342024270Thereafter2,116
#
# AMZN
# acquisitions was allocated as follows (in millions): December 31, 2017 2018 2019 Purchase Price Cash paid, net of cash acquired$13,859 $1,618 $276Indemnification holdback104 31 39 $13,963 $1,649 $315Allocation Goodwill$9,501 $1,228 $189Intangible assets (1): Marketing-related1,987 186 8Contract-based440 285 139Customer-related54 193 14 2,647 677 161Property and equipment3,810 11 3Deferred tax assets117 174 29Other assets acquired1,858 282 41Long-term debt(1,165) (176) (31)Deferred tax liabilities(961) (159) (34)Other liabilities assumed(1,844) (388) (43) $13,963 $1,649 $315 ___________________(1)Intangible assets acquired in 2017, 2018, and 2019 have estimated useful lives of between one and twenty-five years, two
#
# AMZN
# 2019 by segment (in millions): NorthAmerica International AWS ConsolidatedGoodwill - January 1, 2018$11,165 $1,108 $1,077 $13,350New acquisitions (1)1,031 177 20 1,228Other adjustments (2)(5) (15) (10) (30)Goodwill - December 31, 201812,191 1,270 1,087 14,548New acquisitions71 29 89 189Other adjustments (2)2 1 14 17Goodwill - December 31, 2019$12,264 $1,300 $1,190 $14,754 ___________________(1)Primarily includes the acquisitions of Ring and PillPack in the North America segment.(2)Primarily includes changes in foreign exchange rates.
#
# AMZN
# acquired intangible assets as of December 31, 2019 is as follows (in millions): Year Ended December 31,2020$4862021424202239120233342024270Thereafter2,116

# %%
'sdfsdfs. sfsfsf..fs'.replace('.', '.\n')
# Out:
# 'sdfsdfs.\n sfsfsf.\n.\nfs'

# %%
a = ['2',  'sddfs.']
[i[-1] == '.' for i in a]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-7a4a78398c27> in <module>
#       1 a = ['2',  'sddfs.']
# ----> 2 a[[i[-1] == '.' for i in a]]
#
# TypeError: list indices must be integers or slices, not list

# %%
# below unrelated

# %% [markdown]
# ***
# ## Grabbing the Financial Statements
# We now have a nice organized list of all the different components of the 10-K filing, while it won't have all the info it makes the process of getting the data tables a lot easier. We can always revisit the actual text but at this point let's move forward assuming that we want to get the company financial statements. This will include the following:
#
# 1. Balance Sheet
# 2. Statement of Cash Flows
# 3. Income Statement
# 4. Statement of Stock Holder Equity
#
# The first thing we need to do is a loop through each report dictionary, see if the financial statement we are looking for exists in that dictionary and if it does append it to a new list called `url_list`. The `url_list` will contain a URL to each of the statements, and each statement will exist in an HTML format that we can scrape relatively quickly.
#
# ***
# *As a side note, I will be working on a list of report naming conventions across companies. This way, for example, if we want to find the balance sheet we have a list of potential names and IDs we can try.*

# %%
# create the list to hold the statement urls
statements_url = []

for report_dict in master_reports:
    
    # define the statements we want to look for.
    item1 = r"Consolidated Balance Sheets"
    item2 = r"Consolidated Statements of Operations and Comprehensive Income (Loss)"
    item3 = r"Consolidated Statements of Cash Flows"
    item4 = r"Consolidated Statements of Stockholder's (Deficit) Equity"
    
    # store them in a list.
    report_list = [item1, item2, item3, item4]
    
    # if the short name can be found in the report list.
    if report_dict['name_short'] in report_list:
        
        # print some info and store it in the statements url.
        print('-'*100)
        print(report_dict['name_short'])
        print(report_dict['url'])
        
        statements_url.append(report_dict['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Consolidated Balance Sheets
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R2.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Operations and Comprehensive Income (Loss)
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R4.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R5.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Stockholder's (Deficit) Equity
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R6.htm

# %% [markdown]
# ***
# ## Scraping the Financial Statements
# We now have each financial statement's URL that we can now request for the content of that specific statement. The first thing we will need to do is a loop through all the URLs, request each one, and then parse the content. Like the **filing xml summary** up above, I encourage individuals new to scraping the documents to visit each HTML file up above to see what the data looks like.
#
# You'll first notice, it's a simple HTML table. Depending on the statement you're looking at, the structure may be slightly different, but a general hierarchy does exist. My approach to parsing the table falls into three significant steps:
#
# 1. Parsing the table headers.
# 2. Parsing the table rows.
# 3. Parsing the table sections.
#
# I find this approach to be the most reliable as it allows us to loop through each row in the table, but we ask a specific question for each row. The question is, what type of row are you?
#
# Depending on the answer to this question, we can determine which section of the `statement dictionary` the row should be inserted to. Table headers will contain important information regarding the time horizon of the financial statement. Table sections, help us to distinguish different parts of the statement easily.
#
# Finally, table rows contain the data we want to parse. We distinguish these rows, by seeing if certain elements exist in each. For example, only header row would include a `th` tag inside of it; otherwise, it's not considered a header. Section headers contain a `strong` element but no `th` tags.
#
# Hopefully, you're catching on to my approach when it comes to grabbing each row. I ask a simple question to distinguish each row. Once we have the row, we loop through each of the `td` tags, strip text, store it in a list using a list comprehension, and store it in the appropriate section of our statement dictionary.

# %%
# let's assume we want all the statements in a single data set.
statements_data = []

# loop through each statement url
for statement in statements_url:

    # define a dictionary that will store the different parts of the statement.
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the statement file content
    content = requests.get(statement).content
    report_soup = BeautifulSoup(content, 'html')

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(hed_row)
            
        else:            
            print('We encountered an error.')

    # append it to the master list.
    statements_data.append(statement_data)

# %% [markdown]
# ***
# ## Converting the Data into a Data Frame
# Great, we now have all the data for all the financial statements, and it's in a much better structure that will allow us to work with it. We still have some work to do regarding transforming it into the right data type, but we will handle that later. Let's first get it into a data frame, and from there we need to do some massaging to the data.
#
# The first thing we will notice is the index won't work with what we have so we take the first column which contains the indexes and set it as the index. Let's also make sure to rename the index column to something more meaningful.
#
# From here, we need to remove certain characters before we do our type conversion. We can use the `replace` method specifying the `regex` parameter to true. I have to do three separate replace because one handles positive data, one handles negative data, and one handles blank values. After the regex, we can do a type conversion to the whole data frame and then assign our column headers.

# %%
# Grab the proper components
income_header =  statements_data[1]['headers'][1]
income_data = statements_data[1]['data']

# Put the data in a DataFrame
income_df = pd.DataFrame(income_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(income_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
income_df.index = income_df[0]
income_df.index.name = 'Category'
income_df = income_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(income_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
income_df = income_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(income_df.head())

# everything is a string, so let's convert all the data to a float.
income_df = income_df.astype(float)

# Change the column headers
income_df.columns = income_header

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
income_df

# drop the data in a CSV file if need be.
# income_df.to_csv('income_state.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                                   0          1          2   \
# 0                                        Net revenue  $ 134,436  $ 137,156
# 1                                   Cost of services
# 2  Selling, general and administrative, including...
# 3                             Radio conversion costs
# 4  Amortization of subscriber accounts, deferred ...
#
#           3          4          5          6          7          8   \
# 0  $ 135,013  $ 133,753  $ 133,546  $ 138,211  $ 140,498  $ 141,200
# 1
# 2
# 3
# 4
#
#           9          10         11
# 0  $ 540,358  $ 553,455  $ 570,372
# 1    128,939    119,193    115,236
# 2    118,940    155,902    114,152
# 3          0        450     18,422
# 4    211,639    236,788    246,753
# ----------------------------------------------------------------------------------------------------
# Before Regex
# ----------------------------------------------------------------------------------------------------
#                                                            1          2   \
# Category
# Net revenue                                         $ 134,436  $ 137,156
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            3          4   \
# Category
# Net revenue                                         $ 135,013  $ 133,753
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            5          6   \
# Category
# Net revenue                                         $ 133,546  $ 138,211
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            7          8   \
# Category
# Net revenue                                         $ 140,498  $ 141,200
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            9          10  \
# Category
# Net revenue                                         $ 540,358  $ 553,455
# Cost of services                                      128,939    119,193
# Selling, general and administrative, including ...    118,940    155,902
# Radio conversion costs                                      0        450
# Amortization of subscriber accounts, deferred c...    211,639    236,788
#
#                                                            11
# Category
# Net revenue                                         $ 570,372
# Cost of services                                      115,236
# Selling, general and administrative, including ...    114,152
# Radio conversion costs                                 18,422
# Amortization of subscriber accounts, deferred c...    246,753
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
#                                                          1        2        3   \
# Category
# Net revenue                                          134436   137156   135013
# Cost of services                                        NaN      NaN      NaN
# Selling, general and administrative, including ...      NaN      NaN      NaN
# Radio conversion costs                                  NaN      NaN      NaN
# Amortization of subscriber accounts, deferred c...      NaN      NaN      NaN
#
#                                                          4        5        6   \
# Category
# Net revenue                                          133753   133546   138211
# Cost of services                                        NaN      NaN      NaN
# Selling, general and administrative, including ...      NaN      NaN      NaN
# Radio conversion costs                                  NaN      NaN      NaN
# Amortization of subscriber accounts, deferred c...      NaN      NaN      NaN
#
#                                                          7        8        9   \
# Category
# Net revenue                                          140498   141200   540358
# Cost of services                                        NaN      NaN   128939
# Selling, general and administrative, including ...      NaN      NaN   118940
# Radio conversion costs                                  NaN      NaN        0
# Amortization of subscriber accounts, deferred c...      NaN      NaN   211639
#
#                                                          10       11
# Category
# Net revenue                                          553455   570372
# Cost of services                                     119193   115236
# Selling, general and administrative, including ...   155902   114152
# Radio conversion costs                                  450    18422
# Amortization of subscriber accounts, deferred c...   236788   246753
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
#                                                     Dec. 31, 2018  \
# Category
# Net revenue                                              134436.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                 -316590.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                -376911.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Sep. 30, 2018  \
# Category
# Net revenue                                              137156.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                   12280.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -33840.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Jun. 30, 2018  \
# Category
# Net revenue                                              135013.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                 -201845.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                -241792.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Mar. 31, 2018  \
# Category
# Net revenue                                              133753.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                   12012.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -26207.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Dec. 31, 2017  \
# Category
# Net revenue                                              133546.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                   14647.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -14642.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Sep. 30, 2017  \
# Category
# Net revenue                                              138211.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                   12896.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -25536.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Jun. 30, 2017  \
# Category
# Net revenue                                              140498.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                  -11848.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -50104.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Mar. 31, 2017  \
# Category
# Net revenue                                              141200.0
# Cost of services                                              NaN
# Selling, general and administrative, including ...            NaN
# Radio conversion costs                                        NaN
# Amortization of subscriber accounts, deferred c...            NaN
# Depreciation                                                  NaN
# Loss on goodwill impairment                                   NaN
# Total operating expenses                                      NaN
# Operating income (loss)                                   16609.0
# Interest expense                                              NaN
# Unrealized loss on derivative financial instrum...            NaN
# Refinancing expense                                           NaN
# Total other expense                                           NaN
# Loss before income taxes                                      NaN
# Income tax expense (benefit)                                  NaN
# Net loss                                                 -21013.0
# Unrealized gain on derivative contracts, net                  NaN
# Total other comprehensive income, net of tax                  NaN
# Comprehensive loss                                            NaN
#
#                                                     Dec. 31, 2018  \
# Category
# Net revenue                                              540358.0
# Cost of services                                         128939.0
# Selling, general and administrative, including ...       118940.0
# Radio conversion costs                                        0.0
# Amortization of subscriber accounts, deferred c...       211639.0
# Depreciation                                              11434.0
# Loss on goodwill impairment                              563549.0
# Total operating expenses                                1034501.0
# Operating income (loss)                                 -494143.0
# Interest expense                                         180770.0
# Unrealized loss on derivative financial instrum...         3151.0
# Refinancing expense                                       12238.0
# Total other expense                                      196159.0
# Loss before income taxes                                -690302.0
# Income tax expense (benefit)                             -11552.0
# Net loss                                                -678750.0
# Unrealized gain on derivative contracts, net              14378.0
# Total other comprehensive income, net of tax              14378.0
# Comprehensive loss                                      -664372.0
#
#                                                     Dec. 31, 2017  \
# Category
# Net revenue                                              553455.0
# Cost of services                                         119193.0
# Selling, general and administrative, including ...       155902.0
# Radio conversion costs                                      450.0
# Amortization of subscriber accounts, deferred c...       236788.0
# Depreciation                                               8818.0
# Loss on goodwill impairment                                   0.0
# Total operating expenses                                 521151.0
# Operating income (loss)                                   32304.0
# Interest expense                                         145492.0
# Unrealized loss on derivative financial instrum...            0.0
# Refinancing expense                                           0.0
# Total other expense                                      145492.0
# Loss before income taxes                                -113188.0
# Income tax expense (benefit)                              -1893.0
# Net loss                                                -111295.0
# Unrealized gain on derivative contracts, net               1582.0
# Total other comprehensive income, net of tax               1582.0
# Comprehensive loss                                      -109713.0
#
#                                                     Dec. 31, 2016
# Category
# Net revenue                                              570372.0
# Cost of services                                         115236.0
# Selling, general and administrative, including ...       114152.0
# Radio conversion costs                                    18422.0
# Amortization of subscriber accounts, deferred c...       246753.0
# Depreciation                                               8160.0
# Loss on goodwill impairment                                   0.0
# Total operating expenses                                 502723.0
# Operating income (loss)                                   67649.0
# Interest expense                                         127308.0
# Unrealized loss on derivative financial instrum...            0.0
# Refinancing expense                                        9500.0
# Total other expense                                      136808.0
# Loss before income taxes                                 -69159.0
# Income tax expense (benefit)                               7148.0
# Net loss                                                 -76307.0
# Unrealized gain on derivative contracts, net               4589.0
# Total other comprehensive income, net of tax               4589.0
# Comprehensive loss                                       -71718.0
